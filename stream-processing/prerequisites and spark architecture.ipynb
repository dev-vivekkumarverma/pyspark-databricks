# %% [markdown]
# # course prerequisites
# - python programming
# - spark programming
#   - PySpark and Spark API
#   - Dataframe API
#   - Spark SQL

# %% [markdown]
# # what is covered:
# 1.  `spark structure streaming`
# 2.  `Kafka`
# 3.  `Databricks`

# %% [markdown]
# - for sparks infrastructure
#
#   - on cloud
#     - `databricks`
#   - On-premise
#     - `Cloudera`

# %% [markdown]
# - For project building you need `devlopment`, `testing`, `deployment` environments
